# %%
#1. Исследовать на линейную зависимость: 
#𝑓1(𝑥)=𝑒**𝑥 ,𝑓2(𝑥)=1,𝑓3(𝑥)=𝑥+1,𝑓4(𝑥)=𝑥−𝑒**𝑥 . 
# мы видим что f4(x) можно выразить через f1(x), f2(x), f3(x)
# f4(x) = (-1)*f1(x)+(-1)*f2(x)+f3(x) => функции f1, f2, f3, f4 - линейно зависимы

#2.Исследовать на линейную зависимость: 
#𝑓1(𝑥)=2,𝑓2(𝑥)=𝑥,𝑓3(𝑥)=𝑥**2 ,𝑓(4)(𝑥)=(𝑥+1)**2 . 
# т.к мы можем выразить f(4)через f1, f2, f3, f4  f(4) = f3(x)+2*f2(x)+1/2*f3(x) 
# - то функции линейно зависимы

#3. Найти координаты вектора x=(2,3,5)∈R3
#в базисе 𝑏 1 =(0,0,10), 𝑏 2 =(2,0,0) , 𝑏 3 =(0,1,0)
#x=(1,1/3,2)


#4. Найти координаты вектора 3𝑥**2−2*𝑥+2∈ℝ 3 [𝑥] 
#3x2−2x+2∈R3[x]:

#а) в базисе 1 , 𝑥 , x**2 ;

#б) в базисе 𝑥**2 , 𝑥−1 , 1 

#a) (3,-2,2) в базисе (1,1,1) - (1/3,-1/2/,1/2) ?
#б) (3,-2,2) в базисе (1,1,1) - (1/3,-1/2,1/2) ?



#5. Установить, является ли линейным подпространством:

#а) совокупность всех векторов трехмерного пространства, 
#у которых по крайней мере одна из первых двух координат равна нулю;
# возьмет как пример вектора (0,a,b) (с,0,d) (0,k,l).
# проверим первое условие
# (0,a,b) + (с,0,d) + (0,k,l) = (0+c+0,a+0+k,b+d+1) => не соблюдается уловие 1 - не является
#б) все векторы, являющиеся линейными комбинациями данных векторов {u1,u2,...,un}
